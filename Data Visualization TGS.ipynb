# %%
print("[input]")
# Out:
# [input]

# %%
# !ls ./input/
# Out:
# depths.csv            test                  train.csv
# images                test.zip              train.zip
# sample_submission.csv train

# %%
print("="*10)

# %%
print("="*70)

# %%
print("[input/train]")
# Out:
# [input/train]

# %%
# !ls .input/train
# Out:
# ls: .input/train: No such file or directory

# %%
# !ls ./input/train
# Out:
# images masks

# %%
# !ls ./input/train/
# Out:
# images masks

# %%
# !ls ./input/test
# Out:
# 0005bb9630.png 343a049d60.png 66b8883dd0.png 98d115e32d.png cc21d3af94.png
# 000a68e46c.png 343ea5c3b8.png 66c484c763.png 98d2f64d03.png cc233193ba.png
# 000c8dfb2a.png 343fd32150.png 66c5e69234.png 98d30fa576.png cc28f19bce.png
# 000d0a5f6c.png 344395de65.png 66ce83df1c.png 98d374c1f6.png cc2b6a1eb2.png
# 001ef8fc87.png 34453e5f12.png 66ceca6202.png 98ddd20ff1.png cc2c7789b8.png
# 002124aa19.png 3448234dee.png 66d07dd062.png 98e18540a2.png cc2fc654f5.png
# 002af5d1e8.png 3457baa631.png 66d29aed4c.png 98e2d2aba5.png cc30dc52ee.png
# 00323f1910.png 34586dbe50.png 66d52bc03a.png 98e63a2729.png cc31e0720c.png
# 00329dc15c.png 345b80cd1d.png 66dec21f1d.png 98ec81a8df.png cc32da1b7d.png
# 0035c56490.png 34625fbc1c.png 66e0cd3d9b.png 98ef8e3b13.png cc383f3d4d.png
# 0041cb8c49.png 3466c68b0a.png 66e2ec7b55.png 98ef92da51.png cc3cd53279.png
# 0043a01a19.png 346b4c38aa.png 66e42629c1.png 98f28c0303.png cc3fa7233a.png
# ...

# %%
import pandas as pd
import os
import numpy as np
import cv2

# %%
path = os.getcwd()
print(path)
# Out:
# /Users/timothy

# %%
Train_Img = pd.read_csv?

# %%
Train_Img = pd.read_csv

# %%
TRAIN_IMG_PATH = Path

# %%
TRAIN_IMG_PATH = Path

# %%
TRAIN_IMG_PATH = Path
